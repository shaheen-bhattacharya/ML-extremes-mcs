# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
xr.open_dataset(
    "/glade/derecho/scratch/molina/cesm_mcs/mcs_flextrkr_era5/mcstracking_3pctl/2005/mcstrack_20050725_1400.nc"
)["cloudtracknumber"].isel(time=0).plot.pcolormesh("lon","lat")

# %%
xr.open_dataset(
    "/glade/derecho/scratch/molina/cesm_mcs/mcs_flextrkr_era5/mcstracking_3pctl/2005/mcstrack_20050725_1800.nc"
)["cloudtracknumber"].isel(time=0).plot.pcolormesh("lon","lat")
